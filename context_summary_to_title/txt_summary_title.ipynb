# %%
text= ["""


아래 설명하는 갈등의 제목은 서울시 인구소산(人口疏散) 시안(試案) 갈등입니다.


본 갈등의 개요는 다음과 같습니다. 
1) 갈등 개요와 원인 

1970년대 전반까지 정부에 의한 서울의 인구집중 억제는 강북인구의 억제가 주목적이었는데, 이는 무엇보다 안보상의 이유 때문이었다. 1975년 박정희대통령은 연두순시에서 대통령 지시사항 제1호로 ‘서울 강북인구의 강남분산’을 역설하였고, 이에 따라 서울시 인구소산시안이 마련되었다.
대통령 지시사항에 따라 서울시장은 두 가지의 방안을 마련하였는데, 첫째 강북인구가 근원적으로 증가하지 않도록 하고, 둘째 강북에 있는 각종 기관과 인구의 획기적 강남이전정책이었다.
첫째 방안의 연구결과는 ‘4·4조치’로, 앞으로 한강 이북에서는 지목변경을 금지한다는 것이었지만 엄청난 반발로 인해 백지화되었다. 두 번째 방안의 연구결과인 ‘인구억제계획 시안’은 미리 반발이 발생할 것을 예상하여 매스컴에 보도하지 않은 채, 8월 2일 경제차관회의에 정식의안으로 상정하였다. ‘인구억제계획 시안’은 서울시청의 영동(永東; ‘영등포의 동쪽’이라는 의미로 지금의 강남구, 서초구, 송파구, 강동구 일대를 포함한 강남지역을 말함) 이전 및 서울시 인구억제를 위해 주요기관 112개를 강남으로 옮긴다는 내용이었다.
그러나 이 시안은 거의 모든 중앙부처가 관련되어 있을 뿐만 아니라, 엄청난 경비가 소요되는 일이었다. 그러므로 시안의 단계를 벗어나 완전한 정부시책이 되기 위해서는 경제차관회의의 선행검토와 국무회의 등을 통하여 그 타당성 및 실현가능성이 충분히 논의되어야만 했다. 경제차관회의에 상정된 이 시안은 냉담한 중앙정부 및 언론의 반응으로 일단 보류되었고, 그해 11월 28일 중앙정부에 의해 완전히 거부당하였다.
1976년 2월 18일 서울시를 연두순시(年頭巡視)한 박 대통령은 강북인구의 강남이주가 아닌 서울시 인구억제정책임을 강조하였다. 1975년 순시 때와 지시사항 내용이 달라진 것은 그해 일어난 국제정세의 변화, 이른바 공산화의 도미노현상이 원인이었다. 결국 박 대통령의 1976년 지시로 1975년 서울시가 성안하여 경제차관 회의에 상정했던 이른바 ‘서울시 인구억제계획 시안’은 송두리째 무너지고 백지화되었다.

2) 주요 쟁점과 이해당사자 의견 

서울시 인구억제계획 시안의 쟁점은 112개나 되는 기관을 옮기는 경비문제와 강북인구가 강남으로 이전하는 비용 등에 대한 고려 없이 급하게 입안된 점, 그리고 이미 새 청사를 마련한 기관(검찰청건물 등)과 1975년 강북지역에서 이주계획중인 기관(산림청은 홍릉임업시험장으로 이주계획중)들을 다시 강남으로 옮길 시 경비가 2중으로 낭비된다는 점이다.
이 밖에도 서울시의 시책에 일관성이 결여되어 있으며, 공공기관의 이전이 반드시 그에 따른 직원과 가족들의 이주까지 유도할 수 있을 것이라는 전제도 오산이었다. 공공기관이 이전하더라도 종업원과 가족들은 그대로 서울에 근거지를 두고 왕래하기 때문에, 오히려 생활에 2중 부담을 주거나 교통의 불편을 가중시킬 우려가 있는 점 등을 고려하지 못하였다.
학계와 일반시민들은 서울시의 이 같은 도시계획이 종합적 계획이 아닌 즉흥적이고 단견적인 계획이라면서 반대하였다. 많은 시민들이 강북지역의 개발억제와 강남지역 개발촉진이 상호연관성을 갖고는 있으나, 개인재산을 규제하는 식의 개발정책이 되어서는 안 될 뿐만 아니라 새로운 개발지역이 부동산 투기업자들의 투기장으로 변해서는 안 된다고 주장했다. 그리고 강남만 개발하고 강북은 손도 대지 말라는 식의 행정편의주의적 도시개발정책은 강북지역의 주택 과밀화와 강남지역의 토지붐을 조성함으로써, 결과적으로 서민들은 서울생활이 더 어려워 질 수밖에 없으므로 도시개발정책은 재검토되어야 한다는 의견이 지배적이었다. 또한 시민들은 서울시가 아무런 경과조치도 없이 갑자기 사유재산을 규제하는 것은 행정만능 사고방식에서 비롯된 행정의 횡포라고 주장하면서, 옹졸한 도시개발정책을 유보할 것을 건의하였다.
게다가 인구 이전에 앞서 투자를 하고 시민을 끌어들여야 함에도 불구하고, 반대로 시민을 먼저 끌어들인 뒤 나중에 개발을 꾀하는 서울시의 개발행정은 말도 안 되는 것이라고 지적했다. 영동지역의 경우 당초 관공서, 학교, 국영기업체 등을 서둘러 유치하겠다고 발표한 바 있으나, 3만여 평의 상공부단지가 아직 황무지로 남아 있을 뿐만 아니라 이미 완공된 경기고교 신축건물 역시 텅 비어 있는 등 서울시의 강남개발 정책이 말만 앞선 것임을 여실히 보여주고 있다는 것이다.
서울시의 이 같은 도시개발정책에 대해 한양대학교 모(某) 교수는 현재 개발제한구역으로 묶여 있는 그린벨트 안 사유지에 대해서도 사유재산침해라는 등 비난이 많은데, 다시 도심권에 있는 토지에 대해 제2의 조치를 취한다는 것은 너무 심한 처사라고 밝혔다.
또한 도시계획전문가에 따르면 서울의 도시계획은 너무 즉흥적이고 미시적이라서 시장이 바뀔 때마다 도시계획정책도 역시 변경되어 왔다고 지적했다. 그러므로 도시계획은 결과만을 서두르지 말고 기본적이고도 종합적인 연구를 통해 착수해야지, 담당 공무원 몇 사람이 윗사람의 지시에 따라 갑작스럽게 만들어내는 급조형이 되어서는 안 된다고 역설했다. 뿐만 아니라 서울시의 이번 행정 조치에 따라 강북지역에 대한 개간 지목변경 등을 일절 금지한다면 반대급부로 강남지역 토지에 대한 지목변경과 개간 등은 허가해 주는 지의 여부, 강북지역 인구를 강남으로 분산을 유도할 경우 교통소통을 원활히 하기 위한 대책은 무엇인지 구체적인 대안은 제시하지 않은 채 무조건적으로 이루어지는 도시개발정책은 시민생활을 외면하는 것이라고 비판했다. 


본 갈등의 진행경과는 다음에 나열된 시간 순서대로 나열된 사건들과 대응되어 진행되었습니다. 
1975년 박대통령은 연두순시에서 ‘서울 강북인구의 강남분산’을 지시하였고, 이에 따라 서울시는 두 가지의 구체적 방안을 마련하였다. 4월 4일 서울시 간부회의에서 한강 이북에는 지목변경을 금지한다는 것을 주요 내용으로 하는 ‘4․4조치’가 발표되었으나, 엄청난 반발로 백지화되었다. 8월 2일에는 두 번째 안인 ‘인구억제계획 시안’이 경제차관회에 정식의안으로 상정되었다. 하지만 ‘인구억제계획 시안’마저도 냉담한 중앙정부 및 언론의 반응으로 일단 보류되었고, 11월 28일 중앙정부에 의해 완전히 거부당하였다.
1976년 서울시를 연두순시한 박정희대통령은 강북인구의 강남이주가 아니라 ‘서울시 인구억제 정책’을 역설함으로써 서울시가 성안(成案)한 인구억제계획 시안은 송두리째 무너지고 백지화되었다.

진행경과

1975. 1.
1975. 4. 4.
1975. 8. 2.
1975. 8. 5.
1975. 8. 25.

1975. 11. 28. 

1976. 2. 18.
1976. 3. 16.

1976. 4. 2..
1976. 7. 21.
1976. 7. 22.
1977. 2. 10.
1977. 12. 31.
1982. 12. 31.
박정희대통령, 서울시 연두순시 지시사항 제1호 ‘서울 강북 인구의 강남분산’
서울시 간부회의 ‘4․4조치’ “한강 이북 지목변경 금지”발표
서울시, ‘인구억제계획 시안’ 경제차관회의에 상정
‘서울시청 영동 이전-서울시 인구억제 시안으로 주요기관 112개 강남으로’
건설부 고위관료 발표, “수도권 인구분산계획 심의위원회를 설치, 금년안으로 최종안 확정발표 계획”
경제기획원 고위간부, “서울 강북 인구소산책 백지화, 수도권 인구의 기능별 재편방안, 새로운 위성도시 조성 등을 내용으로 수도권 정비계획 수립계획” 발표
박정희대통령, 서울시 연두순시 지시사항 제1호 “서울시 인구집중억제정책”
국무총리 공문서 시달, “서울인구집중과 관련된 정책, 계획 수립시 제1무임소장관실과 사전협조하라”
제1무임소장관실에 수도권 인구집중억제책 전담기구 설치
전담기구 작성, ｢수도권 인구재배치 기본구상｣ 국무총리에게 보고
｢수도권 인구재배치 기본구상｣ 대통령에게 보고
박정희대통령, 임시행정수도 건설구상 발표(서울시 연두순시)
수도권 안구재배치계획을 구체화한 법제 법률 제3069호 공업배치법 발포
수도권정비계획법 법률 제3600호 발포


본 갈등의 발생기간은 1975-01-01 ~ 1976-07-01 로 확인됩니다.


본 갈등의 주체는 정부-정부 로 확인됩니다.


본 갈등의 이해당사자는 청와대, 서울시, 학계 등 전문가 그룹 입니다.


본 갈등 발생 지역은 서울입니다.


본 갈등 처리에 대한 행정 기능의 정의는 지역개발이었습니다.


본 갈등의 성격은 가치갈등로 판단되었습니다.


본 갈등은 해결되었습니다.


본 갈등 발생 당시의 정권은 박정희 정부 시절이었습니다.


본 갈등과 관련한 주요 용어는 다음과 같습니다.
인구소산(人口疏散), 인구소산 시안, 인구소산 정책, 4․4조치, 강남지역 개발


본 갈등 해결과 관련하여 참고된 문헌은 다음과 같습니다.
동아일보 1975. 8. 4. 3면 경향신문 1975. 8. 4. 7면 손정목(2011). ｢서울 도시계획 이야기｣ 제3권. 한울: 332-343. 


URL : http://ffr.krm.or.kr/base/td030/view.html?caseNO=1"""]

# %%
import openai
import spacy
import glob
import time
# Set up your OpenAI API key
openai.api_key = "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"

# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Function to use ChatGPT and get a response from the text
def get_text_response(text):
    gpt_prompt=f"""Provide a text separated by three quotation marks. 
                Summarize it into a sentence of around 30 characters.
                The summarized sentence should end with '~에 관한 갈등'

                \"\"\"{text}\"\"\"
                """
    message=[{"role": "user", "content": gpt_prompt}]
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages = message,
        temperature=0.2,
        max_tokens=1000,
        frequency_penalty=0.0
    )
   
    # response = openai.Completion.create(
    #     engine="gpt-4",  # GPT-3.5 engine
    #     prompt=f"""세 개의 따옴표로 구분된 텍스트가 제공됩니다.
    #             해당 텍스트를 한 문장으로 요약하시오.

    #             \"\"\"{text}\"\"\"
    #             """,
    #     max_tokens=512,  # Control the response length
    #     stop=None  # Optional stop sequence to end the response
    # )
    return response['choices'][0]['message']['content']

if __name__ == "__main__":
    file_path="./conflict_text"
    file_list = glob.glob(file_path + "/*") 
    token =0
    for idx,i in enumerate(file_list):
        # token += len(i)
        # if token >1000:
        #     time.sleep(60)
        #     print("sleep")
        #     token=0
        if idx >2067 and "__MACOSX" not in i:
            print(idx)
            with open(i) as f:
                contents = f.readlines()
                contents=' '.join(contents)
                summary_result=get_text_response(contents[:5500]).replace("\"","").replace("\'","").replace(".","")
                with open(f'./conflict_text_with_summary_title/{summary_result}.txt', 'w') as ff:
                    ff.write(contents)
            time.sleep(60)
            
    # Sample text
    # text = """
    # 좌파 시민운동가 김상구 씨가 쓴 책 ‘김구 청문회’에서는 기본적으로 ‘백범일지’를 역사적 사료로서 가치가 매우 떨어진다고 판단하였다. 저자는 “자서전은 본래 과장될 수밖에 없다. 90% 이상 거짓으로 본다”며 “백범을 우상화하면서 백범일지의 내용이 모두 역사적 사실로 받아들여진 현실이 안타깝다”고 말했다. 실제로 치하포 사건에 대해 백범일지는 피해자 쓰치다를 일본 육군 중위라고 해 마치 국모살해의 원수를 갚은 것으로 표현했지만, 당시 김구를 심문했던 관헌 문서와 언론에는 쓰치다가 일본 상인으로 나온다.
    # """
    # text =["좌파 시민운동가 김상구 씨가 쓴 책 ‘김구 청문회’에서는 기본적으로 ‘백범일지’를 역사적 사료로서 가치가 매우 떨어진다고 판단하였다."," 저자는 “자서전은 본래 과장될 수밖에 없다.", "90% 이상 거짓으로 본다”며 “백범을 우상화하면서 백범일지의 내용이 모두 역사적 사실로 받아들여진 현실이 안타깝다”고 말했다.", "실제로 치하포 사건에 대해 백범일지는 피해자 쓰치다를 일본 육군 중위라고 해 마치 국모살해의 원수를 갚은 것으로 표현했지만, 당시 김구를 심문했던 관헌 문서와 언론에는 쓰치다가 일본 상인으로 나온다."]
    
    # Step 1: Use ChatGPT to get a response from the text
    # r=[]
    # for i in text:
    #     # r.append(get_text_response(text))
    #     print("###############",get_text_response(i))
        # print(i)
        # response = get_completion(prompt_1)
    # print(r)
    # response = get_text_response(text)
    # print("Response:")
    # print(response)
# Out:
# 2068
# 2069
# 2070
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# 2098
# 2099
# 2100
# 2101
# 2102
# 2103
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# 2141
# 2142
# 2143
# 2144
# 2145
# 2146
# 2147
# 2148
# 2149
# 2150
# 2151
# 2152
# 2153
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# 2177
# 2178
# 2179
# 2180
# 2181
# 2182
# 2183
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
# 2192
# 2193
# 2194
# 2195
# 2196
# 2197
# 2198
# 2199
# 2200
# 2201
# 2202
# 2203
# 2204
# 2205
# 2206
# 2207
# 2208
# 2209
# ...

# %%
import openai
from sentence_transformers import util

# import required libraries
import numpy as np
from numpy.linalg import norm

openai.api_key = "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"
def get_embedding(query, engine='text-embedding-ada-002') : 
    res = openai.Embedding.create(
    input=query,
    engine=engine
    )
    return res['data'][0]['embedding']

def return_answer_candidate(query,txt_summary):
    embed_model = "text-embedding-ada-002"
    query_embedding = get_embedding(
                                    query,
                                    engine=embed_model
                                    )
    sim_results={}
    for i in txt_summary:
        summary_embedding =get_embedding(
                                    i,
                                    engine=embed_model
                                    )
        sim_result=float(util.pytorch_cos_sim(summary_embedding, query_embedding)[0][0])
        print(f"{i}:{query} -> {sim_result}")
        if sim_result > 0.85: sim_results[i]=sim_result
    # summary_embedding =get_embedding(
    #                             txt_summary,
    #                             engine=embed_model
    #                             )
    # all_sentences = summary_embedding + [query_embedding]
    # sim_result = np.dot(summary_embedding,query_embedding)/(norm(summary_embedding)*norm(query_embedding))
    # print(sim_result)
    # sim_results1=dict(sorted(sim_results.items(), key=lambda x: x[1], reverse=True))
    # print(sim_results1)
    # print(list(sim_results.keys()))
    sim_results=sorted(sim_results,key=lambda x:sim_results[x], reverse=True)
    print("dddddddddddd",sim_results)
    
    # retrieve from Pinecone
    # res = vectorstore.similarity_search_by_vector(query_embedding, k=3)

    # return res

# %%
txt_summary=['4대강 사업 보 명칭 관련 갈등.txt','음성 LNG 발전소 유치 갈등.txt',
            '제주공항 내국인 면세점 임대료 갈등.txt',
            '덕수초등학교 민주화기념관 건립 갈등.txt','서울 김포공항 소음으로 인한 갈등.txt',
            '제주 해군기지 관련 갈등.txt','광주-무안 공항 갈등.txt','갈등관리를 위한 창원시 스타필드 입점 공론화 사례분석.pdf']
query="창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘"
return_answer_candidate(query,txt_summary)
# Out:
# 4대강 사업 보 명칭 관련 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.7993449568748474
# 음성 LNG 발전소 유치 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.7857943773269653
# 제주공항 내국인 면세점 임대료 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.8015749454498291
# 덕수초등학교 민주화기념관 건립 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.7885187864303589
# 서울 김포공항 소음으로 인한 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.7808283567428589
# 제주 해군기지 관련 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.8074248433113098
# 광주-무안 공항 갈등.txt:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.7759531736373901
# 갈등관리를 위한 창원시 스타필드 입점 공론화 사례분석.pdf:창원시 스타필드 관련 사례의 {갈등 원인}, {주요 쟁점} , {이해 당사자 의견} , {해결 방안}을 구분해서 요약해줘 -> 0.8913837671279907
# dddddddddddd ['갈등관리를 위한 창원시 스타필드 입점 공론화 사례분석.pdf']

# %%
str(None)
# Out:
# 'None'
